# %% [markdown]
# <a href="https://colab.research.google.com/github/victormaciase/Energy/blob/main/CapacidadGeneracion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# URL raw del archivo Excel en GitHub
url_data = "https://raw.githubusercontent.com/victormaciase/Energy/main/datos/se_capacidad_instalada_gx.csv"

df = pd.read_csv(url_data, sep=';')

# %%
df.head()
# Out:
#   sistema subsistema propietario                     razon_social  \
# 0     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 1     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 2     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 3     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 4     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
#
#             rut          central        estado fecha_puesta_servicio_central  \
# 0  88.272.600-2  ALTO BAGUALES 2  En Operacion                    01/01/2016
# 1  88.272.600-2  ALTO BAGUALES 2  En Operacion                    01/01/2016
# 2  88.272.600-2    AYSEN TÉRMICO  En Operacion                    01/01/1997
# 3  88.272.600-2    AYSEN TÉRMICO  En Operacion                    01/01/1997
# 4  88.272.600-2            AYSEN  En Operacion                    01/01/1960
#
#    anio_servicio_central                                  region_nombre  ...  \
# 0                 2016.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 1                 2016.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 2                 1997.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 3                 1997.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 4                 1960.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
#
#   unidad_3 tipo_turbina_hidraulica gasto_m3_por_s  caida_m coord_este_utm  \
# 0      NaN                     NaN            NaN      NaN    726258,7977
# 1      NaN                     NaN            NaN      NaN    726258,7977
# 2      NaN                     NaN            NaN      NaN    679309,0822
# 3      NaN                     NaN            NaN      NaN    679309,0822
# 4      NaN                 Francis            3,3      103    679309,0822
#
#   coord_norte_utm huso_utm                 tipo_final orden   fecha_act
# 0     5045322,821      18S                     Eólica  15.0  10/08/2026
# 1     5045322,821      18S                     Eólica  15.0  10/08/2026
# 2     5027217,691      18S            Petróleo Diesel  15.0  10/08/2026
# 3     5027217,691      18S            Petróleo Diesel  15.0  10/08/2026
# 4     5027217,691      18S  Mini Hidráulica de Pasada  15.0  10/08/2026
#
# [5 rows x 42 columns]

# %% [markdown]
# Filtrando solo plantas en operación, se tiene:

# %%
df1 = df[(df['estado'] == "En Operacion") &
 (df['region_nombre'] != "Salta (Argentina)") &
  (df['sistema'].isin(['SEN', 'SEA', 'SEM']))]
df1.head()
# Out:
#   sistema subsistema propietario                     razon_social  \
# 0     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 1     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 2     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 3     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
# 4     SEA      AYSEN   EDELAYSEN  Empresa Eléctrica de Aisén S.A.
#
#             rut          central        estado fecha_puesta_servicio_central  \
# 0  88.272.600-2  ALTO BAGUALES 2  En Operacion                    01/01/2016
# 1  88.272.600-2  ALTO BAGUALES 2  En Operacion                    01/01/2016
# 2  88.272.600-2    AYSEN TÉRMICO  En Operacion                    01/01/1997
# 3  88.272.600-2    AYSEN TÉRMICO  En Operacion                    01/01/1997
# 4  88.272.600-2            AYSEN  En Operacion                    01/01/1960
#
#    anio_servicio_central                                  region_nombre  ...  \
# 0                 2016.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 1                 2016.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 2                 1997.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 3                 1997.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
# 4                 1960.0  Región Aisén del Gral.Carlos Ibáñez del Campo  ...
#
#   unidad_3 tipo_turbina_hidraulica gasto_m3_por_s  caida_m coord_este_utm  \
# 0      NaN                     NaN            NaN      NaN    726258,7977
# 1      NaN                     NaN            NaN      NaN    726258,7977
# 2      NaN                     NaN            NaN      NaN    679309,0822
# 3      NaN                     NaN            NaN      NaN    679309,0822
# 4      NaN                 Francis            3,3      103    679309,0822
#
#   coord_norte_utm huso_utm                 tipo_final orden   fecha_act
# 0     5045322,821      18S                     Eólica  15.0  10/08/2026
# 1     5045322,821      18S                     Eólica  15.0  10/08/2026
# 2     5027217,691      18S            Petróleo Diesel  15.0  10/08/2026
# 3     5027217,691      18S            Petróleo Diesel  15.0  10/08/2026
# 4     5027217,691      18S  Mini Hidráulica de Pasada  15.0  10/08/2026
#
# [5 rows x 42 columns]

# %% [markdown]
# El número de observaciones por sistema es:

# %%
df1['sistema'].value_counts()
# Out:
# sistema
# SEN    1203
# SEA      63
# SEM      54
# Name: count, dtype: int64

# %%
df1['potencia_bruta_mw'] = df1['potencia_bruta_mw'].str.replace(',', '.', regex=False).astype(float)
df1.groupby('region_nombre')['potencia_bruta_mw'].sum()
# Out:
# /tmp/ipykernel_688/1551394683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['potencia_bruta_mw'] = df1['potencia_bruta_mw'].str.replace(',', '.', regex=False).astype(float)
# region_nombre
# Región Aisén del Gral.Carlos Ibáñez del Campo        67.570000
# Región Metropolitana de Santiago                   2453.168516
# Región de Antofagasta                             11465.577600
# Región de Arica y Parinacota                        167.778200
# Región de Atacama                                  5574.985700
# Región de Coquimbo                                 2118.369180
# Región de La Araucanía                             1126.205500
# Región de Los Lagos                                 971.347150
# Región de Los Ríos                                  359.759950
# Región de Magallanes y de la Antártica Chilena      142.978000
# Región de Tarapacá                                  673.806900
# Región de Valparaíso                               3537.485422
# Región de Ñuble                                     412.317670
# Región del Biobío                                  5438.878220
# Región del Libertador Gral. Bernardo O’Higgins     2176.382940
# Región del Maule                                   2897.491699
# Name: potencia_bruta_mw, dtype: float64

# %%
df1['potencia_neta_mw'] = df1['potencia_neta_mw'].str.replace(',', '.', regex=False).astype(float)
df1.groupby('region_nombre')['potencia_neta_mw'].sum()
# Out:
# /tmp/ipykernel_688/1666231072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['potencia_neta_mw'] = df1['potencia_neta_mw'].str.replace(',', '.', regex=False).astype(float)
# region_nombre
# Región Aisén del Gral.Carlos Ibáñez del Campo        67.484000
# Región Metropolitana de Santiago                   2402.430915
# Región de Antofagasta                             11069.848200
# Región de Arica y Parinacota                        166.719800
# Región de Atacama                                  5424.926000
# Región de Coquimbo                                 2086.435080
# Región de La Araucanía                             1100.293700
# Región de Los Lagos                                 961.094810
# Región de Los Ríos                                  357.224600
# Región de Magallanes y de la Antártica Chilena      128.680200
# Región de Tarapacá                                  654.871665
# Región de Valparaíso                               3441.017550
# Región de Ñuble                                     404.979450
# Región del Biobío                                  5186.816700
# Región del Libertador Gral. Bernardo O’Higgins     2136.927530
# Región del Maule                                   2848.545880
# Name: potencia_neta_mw, dtype: float64

# %%
print(df1.columns)
# Out:
# Index(['sistema', 'subsistema', 'propietario', 'razon_social', 'rut',
#        'central', 'estado', 'fecha_puesta_servicio_central',
#        'anio_servicio_central', 'region_nombre', 'comuna_nombre', 'cod_unidad',
#        'tipo_unidad', 'fecha_servicio_unidad', 'unidades', 'marca_modelo',
#        'clasificacion', 'tipo_de_energia', 'potencia_bruta_mw',
#        'potencia_neta_mw', 'ley_ernc', 'medio_generacion', 'distribuidora',
#        'punto_conexion', 'combustible_1', 'consumo_1', 'unidad_1',
#        'combustible_2', 'consumo_2', 'unidad_2', 'combustible_3', 'consumo_3',
#        'unidad_3', 'tipo_turbina_hidraulica', 'gasto_m3_por_s', 'caida_m',
#        'coord_este_utm', 'coord_norte_utm', 'huso_utm', 'tipo_final', 'orden',
#        'fecha_act'],
#       dtype='object')

# %%
df1.groupby('tipo_de_energia')['potencia_neta_mw'].sum()
# Out:
# tipo_de_energia
# Biogas                       58.457100
# Biomasa                     519.690500
# Biomasa-Petróleo N°6         88.000000
# Carbón                     2809.688000
# Carbón - Petcoke            702.659000
# Cogeneración                 20.068200
# Eólica                     6310.425300
# Fuel Oil Nro. 6              35.435465
# Gas Natural                3863.729300
# Geotérmica                   83.580000
# Hidráulica Embalse         3503.572600
# Hidráulica Pasada          3432.044550
# Mini Hidráulica Pasada      576.055375
# Petcoke                      20.500000
# Petróleo Diesel            3850.469530
# Propano                      14.610000
# Solar                     12438.081160
# Solar Fotovoltaica            2.960000
# Solar-CSP                   108.270000
# Name: potencia_neta_mw, dtype: float64

# %%
df1['tipo_de_energia2'] = df1['tipo_de_energia'].replace({
    'Solar Fotovoltaica': 'Solar',
    'Solar-CSP': 'Solar',
    'Carbón - Petcoke': 'Carbón',
    'Petcoke': 'Carbón',
    'Mini Hidráulica Pasada': 'Hidráulica',
    'Hidráulica Pasada': 'Hidráulica',
    'Hidráulica Embalse': 'Hidráulica',
    'Cogeneración': 'Gas Natural',
    'Propano': 'Gas Natural',
    'Biogas': 'Biomasa',
    'Biomasa-Petróleo N°6': 'Biomasa',
    'Fuel Oil Nro. 6': 'Petróleo Diesel'

})

print("Nuevas categorías de 'tipo_de_energia' después de agrupar:")
df1['tipo_de_energia2'].value_counts()
# Out:
# Nuevas categorías de 'tipo_de_energia' después de agrupar:
# /tmp/ipykernel_688/326730095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['tipo_de_energia2'] = df1['tipo_de_energia'].replace({
# tipo_de_energia2
# Solar              759
# Petróleo Diesel    204
# Hidráulica         194
# Eólica              73
# Gas Natural         46
# Biomasa             32
# Carbón              11
# Geotérmica           1
# Name: count, dtype: int64

# %%
df1.groupby('tipo_de_energia2')['potencia_neta_mw'].sum()
# Out:
# tipo_de_energia2
# Biomasa              666.147600
# Carbón              3532.847000
# Eólica              6310.425300
# Gas Natural         3898.407500
# Geotérmica            83.580000
# Hidráulica          7511.672525
# Petróleo Diesel     3885.904995
# Solar              12549.311160
# Name: potencia_neta_mw, dtype: float64

# %%
df1.groupby('sistema')['potencia_neta_mw'].sum().round(0)
# Out:
# sistema
# SEA       74.0
# SEM      129.0
# SEN    38236.0
# Name: potencia_neta_mw, dtype: float64

# %%
df1[df1['sistema'] == "SEA"].groupby('tipo_de_energia2')['potencia_neta_mw'].sum().round(0)
# Out:
# tipo_de_energia2
# Eólica              2.0
# Hidráulica         25.0
# Petróleo Diesel    44.0
# Solar               3.0
# Name: potencia_neta_mw, dtype: float64

# %%
df1[df1['sistema'] == "SEM"].groupby('tipo_de_energia2')['potencia_neta_mw'].sum().round(0)
# Out:
# tipo_de_energia2
# Eólica             12.0
# Gas Natural        99.0
# Petróleo Diesel    18.0
# Name: potencia_neta_mw, dtype: float64

# %%
df1[df1['sistema'] == "SEN"].groupby('tipo_de_energia2')['potencia_neta_mw'].sum().round(0)
# Out:
# tipo_de_energia2
# Biomasa              666.0
# Carbón              3533.0
# Eólica              6297.0
# Gas Natural         3799.0
# Geotérmica            84.0
# Hidráulica          7486.0
# Petróleo Diesel     3824.0
# Solar              12546.0
# Name: potencia_neta_mw, dtype: float64

# %%
import plotly.express as px

df_sen = df1[df1['sistema'] == "SEN"]

# Agrupar por tipo_de_energia y sumar la potencia bruta
df_treemap = df_sen.groupby('tipo_de_energia2')['potencia_neta_mw'].sum().reset_index()

# Crear el treemap
fig = px.treemap(df_treemap, path=[px.Constant("SEN"), 'tipo_de_energia2'],
                 values='potencia_neta_mw',
                 title='Distribución de Potencia Neta (MW) por Tipo de Energía en la Región de Los Lagos')

fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e2fb45d6-8a79-4f71-b21c-36e4454db589" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2fb45d6-8a79-4f71-b21c-36e4454db589")) {                    Plotly.newPlot(                        "e2fb45d6-8a79-4f71-b21c-36e4454db589",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003epotencia_neta_mw=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["SEN\u002fBiomasa","SEN\u002fCarbón","SEN\u002fEólica","SEN\u002fGas Natural","SEN\u002fGeotérmica","SEN\u002fHidráulica","SEN\u002fPetróleo Diesel","SEN\u002fSolar","SEN"],"labels":["Biomasa","Carbón","Eólica","Gas Natural","Geotérmica","Hidráulica","Petróleo Diesel","Solar","SEN"],"name":"","parents":["SEN","SEN","SEN","SEN","SEN","SEN","SEN","SEN",""],"values":[666.1476,3532.8469999999998,6297.0153,3799.1375000000003,83.58,7486.232525,3824.466795,12546.35116,38235.77788],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...
